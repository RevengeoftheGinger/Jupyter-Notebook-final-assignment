# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #TITLE<br>
# #FINAL ASSIGNMENT FOR JUPYTER NOTEBOOK<br>

# %% [markdown]
# #Introduction<br>
# #This Notebook will be used to display some core concepts for Jupyter Notebook and the lessons I learned during this course.<br>

# %% [markdown]
# #Data Science Languages<br>
# #Python<br>
# #SQL<br>
# #R<br>
# #Scala<br>
# #Java<br>

# %% [markdown]
# #Data Science Libraries<br>
# #Numpy<br>
# #Pandas<br>
# #Scikit-learn<br>
# #Matplotlib<br>
# #Seaborn<br>
# #Tensorflow<br>

# %% [markdown]
# #Cell for arithmetic expression<br>
# <br>
# a = 1<br>
# b = 2<br>
# c = 3<br>
# d = 4<br>
# e = a+b+c+d<br>

# %%
#Cell for multiplication

a = 2
b = 3
c = a * b
d = a + b

# %%
#Cell for converting minutes to hours

minutes_to_hours = 640 // 60
minutes_to_hours

# %% [markdown]
# Objectives in this assignment:
# <br>
# Create a Title<br>
# Create an introduction<br>
# List several data science languages<br>
# List several data science libraries<br>
# Create a cell showcasing arithmetic expression<br>
# Create 2 code cells showcasing multiplication, and converting minutes into hours<br>

# %% [markdown]
# Author Name: Drew Young
