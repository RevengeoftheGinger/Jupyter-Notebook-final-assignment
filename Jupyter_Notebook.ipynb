# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <H1>#TITLE<br>
# <H1>#FINAL ASSIGNMENT FOR JUPYTER NOTEBOOK<br>

# %% [markdown]
# #Introduction<br>
# #This Notebook will be used to display some core concepts for Jupyter Notebook and the lessons I learned during this course.<br>

# %% [markdown]
# <b>Objectives:</b>
# <br>
# * Creating and modifying cells in Jupyter Notebook<br>
# * Performing calculations within Jupyter Notebook<br>
# * List popular data science languages<br>
# * List popular data science libraries<br>

# %% [markdown]
# Data Science Languages<br>
# 1. Python<br>
# 2. SQL<br>
# 3. R<br>
# 4. Scala<br>
# 5. Java<br>

# %% [markdown]
# Data Science Libraries<br>
# 1. Numpy<br>
# 2. Pandas<br>
# 3. Scikit-learn<br>
# 4. Matplotlib<br>
# 5. Seaborn<br>

# %% [markdown]
# |Data Science Tools|
# |----------------------|
# |Jupyter Notebook|
# |TensorFlow|
# |Apache Spark|
# |RStudio|
# |Apache Hadoop|

# %% [markdown]
# <H3>Cell for arithmetic expression<br>
# <br>
# a = 1<br>
# b = 2<br>
# c = 3<br>
# d = 4<br>
# e = a+b+c+d<br>

# %%
#Cell for multiplication

a = 2
b = 3
c = a * b
d = a + b

# %%
#Cell for converting minutes to hours

minutes_to_hours = 640 // 60
minutes_to_hours

# %% [markdown]
# <H2>Author: <br>
# <H2>Drew Young
